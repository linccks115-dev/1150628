# %%
Name=input("Enter your name: ")
print("Hello, " + Name + "! Welcome to the program.")
# Out:
# Hello, colin! Welcome to the program.

# %%
num1=input("請輸入數字1")
num2=input("請輸入數字2")
print("數字1是: " + num1)
print("數字2是: " + num2)
print("數字1+數字2是: " + num1 + "+" + num2 + "=" + str(int(num1)+int(num2)))
# Out:
# 數字1是: 5
# 數字2是: 6
# 數字1+數字2是: 5+6=11
